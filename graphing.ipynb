# %%
import pandas as pd

df = pd.read_csv('data/avocado.csv')

albany_df = df[df['region'] == 'Albany']
albany_df.set_index('Date', inplace=True)

albany_df['AveragePrice'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df = pd.read_csv('data/avocado.csv')
df['Date'] = pd.to_datetime(df['Date'])

# %%
albany_df = df[df['region'] == 'Albany']
albany_df.set_index('Date', inplace=True)

albany_df['AveragePrice'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
albany_df.sort_index(inplace=True)
# Out:
# /tmp/ipykernel_7506/2345733865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df.sort_index(inplace=True)

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()
# Out:
# /tmp/ipykernel_7506/3897989630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()

# %%
albany_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
# 2015-01-11          50          1.77       1182.56    39.00    305.12    0.00
# 2015-01-18          49          1.17      44511.28   914.14  31540.32  135.77
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04     9716.46     9186.93      529.53          0.0  conventional
# 2015-01-04     1162.65     1162.65        0.00          0.0       organic
# 2015-01-11     8424.77     8036.04      388.73          0.0  conventional
# 2015-01-11      838.44      838.44        0.00          0.0       organic
# 2015-01-18    11921.05    11651.09      269.96          0.0  conventional
#
#             year  region  price25ma
# Date
# 2015-01-04  2015  Albany        NaN
# 2015-01-04  2015  Albany        NaN
# 2015-01-11  2015  Albany        NaN
# 2015-01-11  2015  Albany        NaN
# 2015-01-18  2015  Albany        NaN

# %%
albany_df.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-11           2          1.68       2570.52    131.67     229.56
# 2018-03-18           1          1.66       3154.45    275.89     297.96
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-11   0.00     2209.29     2209.29        0.00          0.0
# 2018-03-18   0.00     2580.60     2577.27        3.33          0.0
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
#
#                     type  year  region  price25ma
# Date
# 2018-03-11       organic  2018  Albany     1.4224
# 2018-03-18       organic  2018  Albany     1.4316
# 2018-03-18  conventional  2018  Albany     1.4276
# 2018-03-25  conventional  2018  Albany     1.4272
# 2018-03-25       organic  2018  Albany     1.4368

# %%
albany_df = df.copy()[df['region']=='Albany']
albany_df.set_index('Date', inplace=True)
albany_df.sort_index(inplace=True)
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()

# %%
df['region']
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
#                ...
# 18244    WestTexNewMexico
# 18245    WestTexNewMexico
# 18246    WestTexNewMexico
# 18247    WestTexNewMexico
# 18248    WestTexNewMexico
# Name: region, Length: 18249, dtype: object

# %%
df['region'].values
# Out:
# array(['Albany', 'Albany', 'Albany', ..., 'WestTexNewMexico',
#        'WestTexNewMexico', 'WestTexNewMexico'], dtype=object)

# %%
df['region'].values.tolist()
# Out:
# ['Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'BaltimoreWashington',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boise',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'Boston',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'BuffaloRochester',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'California',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Charlotte',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'Chicago',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'CincinnatiDayton',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'Columbus',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'DallasFtWorth',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Denver',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'Detroit',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GrandRapids',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'HartfordSpringfield',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Houston',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  'Indianapolis',
#  ...]

# %%
print(set(df['region'].values.tolist()))
# Out:
# {'GrandRapids', 'NorthernNewEngland', 'CincinnatiDayton', 'DallasFtWorth', 'BuffaloRochester', 'Chicago', 'HartfordSpringfield', 'Portland', 'Detroit', 'LosAngeles', 'Denver', 'Sacramento', 'SanFrancisco', 'Northeast', 'TotalUS', 'California', 'MiamiFtLauderdale', 'StLouis', 'SouthCarolina', 'Midsouth', 'Pittsburgh', 'Southeast', 'BaltimoreWashington', 'Syracuse', 'West', 'LasVegas', 'RichmondNorfolk', 'Atlanta', 'Jacksonville', 'Orlando', 'Tampa', 'SanDiego', 'Spokane', 'GreatLakes', 'WestTexNewMexico', 'NewOrleansMobile', 'Houston', 'PhoenixTucson', 'Albany', 'Philadelphia', 'Plains', 'Seattle', 'SouthCentral', 'NewYork', 'Nashville', 'Columbus', 'HarrisburgScranton', 'Louisville', 'RaleighGreensboro', 'Boston', 'Indianapolis', 'Charlotte', 'Boise', 'Roanoke'}

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
len(df['region'].unique())
# Out:
# 54

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique()[:16]:
    print(region)
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma'] = region_df['AveragePrice'].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
# Date column contains duplicate values because avocado has multiple prices.
graph_df.tail()
# Out:
#             Albany_price25ma  Atlanta_price25ma  \
# Date
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
#
#             BaltimoreWashington_price25ma  Boise_price25ma  Boston_price25ma  \
# Date
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
#
#             BuffaloRochester_price25ma  California_price25ma  \
# Date
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
#
#             Charlotte_price25ma  Chicago_price25ma  \
# Date
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
#
#             CincinnatiDayton_price25ma  Columbus_price25ma  \
# Date
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
#
#             DallasFtWorth_price25ma  Denver_price25ma  Detroit_price25ma  \
# Date
# 2018-03-25                    1.118            1.2888             1.1492
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
#
#             GrandRapids_price25ma  GreatLakes_price25ma
# Date
# 2018-03-25                 1.3264                1.2788
# 2018-03-25                 1.3164                1.2568
# 2018-03-25                 1.3164                1.2788
# 2018-03-25                 1.3264                1.2568
# 2018-03-25                 1.3264                1.2788

# %%
import pandas as pd

df = pd.read_csv('data/avocado.csv')
df = df.copy()[df['type'] == 'organic']

df['Date'] = pd.to_datetime(df['Date'])

df.sort_values(by='Date', ascending=True, inplace=True)
df.head()
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume       4046      4225  \
# 9489           51 2015-01-04          1.24     142349.77  107490.73  25711.96
# 10269          51 2015-01-04          1.50       6329.83    3730.80   2141.91
# 10893          51 2015-01-04          1.12      17296.85   14569.66   1868.59
# 9437           51 2015-01-04          1.73        379.82       0.00     59.82
# 11621          51 2015-01-04          1.30       5782.70     723.29   4221.15
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9489   2.93     9144.15     9144.15        0.00          0.0  organic  2015
# 10269  0.00      457.12      426.67       30.45          0.0  organic  2015
# 10893  0.00      858.60      830.00       28.60          0.0  organic  2015
# 9437   0.00      320.00      320.00        0.00          0.0  organic  2015
# 11621  0.00      838.26      223.33      614.93          0.0  organic  2015
#
#                  region
# 9489         California
# 10269          LasVegas
# 10893     PhoenixTucson
# 9437   BuffaloRochester
# 11621           Spokane

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique():
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma'] = region_df['AveragePrice'].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma']]
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])

graph_df.tail()
# Out:
#             California_price25ma  LasVegas_price25ma  PhoenixTucson_price25ma  \
# Date
# 2018-02-25                1.9128              1.9120                   1.7468
# 2018-03-04                1.8876              1.8748                   1.7404
# 2018-03-11                1.8636              1.8440                   1.7324
# 2018-03-18                1.8516              1.8204                   1.7216
# 2018-03-25                1.8364              1.7968                   1.7104
#
#             BuffaloRochester_price25ma  Spokane_price25ma  \
# Date
# 2018-02-25                      1.2912             2.1544
# 2018-03-04                      1.2744             2.1040
# 2018-03-11                      1.2652             2.0552
# 2018-03-18                      1.2560             2.0012
# 2018-03-25                      1.2416             1.9496
#
#             LosAngeles_price25ma  Philadelphia_price25ma  Boston_price25ma  \
# Date
# 2018-02-25                1.9024                  1.6324            1.7636
# 2018-03-04                1.8656                  1.6260            1.7708
# 2018-03-11                1.8284                  1.6300            1.7824
# 2018-03-18                1.8160                  1.6304            1.7932
# 2018-03-25                1.8016                  1.6256            1.7984
#
#             StLouis_price25ma  Louisville_price25ma  ...  Houston_price25ma  \
# Date                                                 ...
# 2018-02-25             1.9240                1.7044  ...             1.6132
# 2018-03-04             1.8868                1.6816  ...             1.5960
# 2018-03-11             1.8468                1.6508  ...             1.5696
# 2018-03-18             1.8192                1.6176  ...             1.5360
# 2018-03-25             1.7976                1.5844  ...             1.5128
#
#             Chicago_price25ma  Plains_price25ma  Indianapolis_price25ma  \
# Date
# 2018-02-25             1.8160            1.8116                  1.4928
# 2018-03-04             1.8024            1.7900                  1.4744
# 2018-03-11             1.7836            1.7672                  1.4540
# 2018-03-18             1.7732            1.7452                  1.4320
# 2018-03-25             1.7672            1.7232                  1.4160
#
#             SouthCentral_price25ma  Columbus_price25ma  Albany_price25ma  \
# Date
# 2018-02-25                  1.5728              1.6064            1.5112
# 2018-03-04                  1.5592              1.5804            1.4992
# 2018-03-11                  1.5400              1.5496            1.5044
# 2018-03-18                  1.5204              1.5088            1.5140
# 2018-03-25                  1.5072              1.4848            1.5188
#
#             Detroit_price25ma  NewOrleansMobile_price25ma  NewYork_price25ma
# Date
# 2018-02-25             1.4980                      1.5384             1.9308
# 2018-03-04             1.4692                      1.5288             1.9156
# 2018-03-11             1.4444                      1.5076             1.9092
# 2018-03-18             1.4092                      1.4860             1.8948
# 2018-03-25             1.3964                      1.4616             1.8876
#
# [5 rows x 54 columns]

# %%
graph_df.plot(figsize=(8,5), legend=False)
# Out:
# <AxesSubplot: xlabel='Date'>
