# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/min_wage_utf8.csv')

act_min_wage = pd.DataFrame()

for name, group in df.groupby('State'):
    if act_min_wage.empty:
        act_min_wage = group.set_index('Year')[['Low.2018']].rename(columns={'Low.2018': name})
    else:
        act_min_wage = act_min_wage.join(group.set_index('Year')[['Low.2018']].rename(columns={'Low.2018': name}))

act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.12     3.37      1.12       11.88      7.20        10.08
# 1969      0.0   14.33     3.19      1.07       11.26      6.83         9.56
# 1970      0.0   13.54     3.02      7.09       10.64      6.45        10.32
# 1971      0.0   12.99     2.89      6.80       10.20      6.18         9.89
# 1972      0.0   12.57     2.80      7.19        9.88      5.99        11.08
#
#       Delaware  District of Columbia  Federal (FLSA)  ...  Tennessee  Texas  \
# Year                                                  ...
# 1968      9.00                  9.00            8.28  ...        0.0   0.00
# 1969      8.53                  8.53            7.85  ...        0.0   0.00
# 1970      8.06                 10.32            8.38  ...        0.0   0.00
# 1971      7.73                  9.89            8.04  ...        0.0   0.00
# 1972      9.58                  9.58            9.58  ...        0.0   8.38
#
#       U.S. Virgin Islands  Utah  Vermont  Virginia  Washington  West Virginia  \
# Year
# 1968                  NaN  7.20    10.08       0.0       11.52           7.20
# 1969                  NaN  6.83     9.56       0.0       10.92           6.83
# 1970                  NaN  6.45    10.32       0.0       10.32           6.45
# 1971                  NaN  6.18     9.89       0.0        9.89           6.18
# 1972                  NaN  7.19     9.58       0.0        9.58           7.19
#
#       Wisconsin  Wyoming
# Year
# 1968       9.00     8.64
# 1969       8.53     8.19
# 1970       8.38     8.38
# 1971       8.04     8.04
# 1972       8.68     8.98
#
# [5 rows x 55 columns]

# %%
min_wage_corr = act_min_wage.replace(0, np.NaN).dropna(axis=1).corr()
min_wage_corr.head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.377934    0.717653 -0.129332     0.680886  0.258997
# Arkansas    -0.377934  1.000000   -0.234367  0.135749     0.047580  0.016125
# California   0.717653 -0.234367    1.000000  0.483313     0.876215  0.479197
# Colorado    -0.129332  0.135749    0.483313  1.000000     0.402020  0.566304
# Connecticut  0.680886  0.047580    0.876215  0.402020     1.000000  0.552613
#
#              District of Columbia  Federal (FLSA)      Guam    Hawaii  ...  \
# Alaska                   0.321785        0.637679  0.787915  0.672620  ...
# Arkansas                 0.266889        0.117245  0.039593  0.204801  ...
# California               0.596865        0.371966  0.492052  0.519241  ...
# Colorado                 0.673371       -0.232035 -0.192616  0.069800  ...
# Connecticut              0.652488        0.487750  0.632073  0.621503  ...
#
#              Pennsylvania  Puerto Rico  Rhode Island  South Dakota      Utah  \
# Alaska           0.610814    -0.038118      0.652353     -0.326316 -0.020462
# Arkansas         0.159923     0.232186      0.003498      0.800116  0.194680
# California       0.429061     0.512712      0.780916     -0.036787  0.392898
# Colorado        -0.136195     0.657364      0.429852      0.399137  0.622330
# Connecticut      0.531769     0.626712      0.802485      0.105707  0.302538
#
#               Vermont  Washington  West Virginia  Wisconsin   Wyoming
# Alaska       0.663558    0.411593       0.044814   0.702570  0.727932
# Arkansas     0.087429   -0.072343       0.420819   0.000470 -0.250592
# California   0.877922    0.754085       0.371765   0.584067  0.722617
# Colorado     0.448485    0.612637       0.533623   0.011501  0.130053
# Connecticut  0.898469    0.715691       0.400099   0.585790  0.814971
#
# [5 rows x 39 columns]

# %%
import matplotlib.pyplot as plt

plt.matshow(min_wage_corr)
plt.show()

# %%
labels = [c[:2] for c in min_wage_corr.columns]

fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)
ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(labels)))
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

plt.show()

# %%
# !pip install lxml html5lib bs4 requests
# Out:
# Requirement already satisfied: lxml in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (4.9.1)
# Requirement already satisfied: html5lib in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (1.1)
# Requirement already satisfied: bs4 in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (0.0.1)
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: six>=1.9 in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: beautifulsoup4 in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (from bs4) (4.11.1)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: soupsieve>1.2 in /home/bcp/miniconda3/envs/da/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# Installing collected packages: urllib3, charset-normalizer, requests
# Successfully installed charset-normalizer-2.1.1 requests-2.28.1 urllib3-1.26.13

# %%
import requests

web = requests.get("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")
dfs = pd.read_html(web.text)

# %%
for df in dfs:
    print(df.head())  # one is states, the other territory
# Out:
#   State Name/District Postal Abbreviation Postal Code
# 0             Alabama                Ala.          AL
# 1              Alaska              Alaska          AK
# 2             Arizona               Ariz.          AZ
# 3            Arkansas                Ark.          AR
# 4          California              Calif.          CA
#         Territory/Associate Abbreviation Postal Code
# 0            American Samoa          NaN          AS
# 1                      Guam         Guam          GU
# 2          Marshall Islands          NaN          MH
# 3                Micronesia          NaN          FM
# 4  Northern Mariana Islands          NaN          MP

# %%
state_abbv = dfs[0]
state_abbv.head()
# Out:
#   State Name/District Postal Abbreviation Postal Code
# 0             Alabama                Ala.          AL
# 1              Alaska              Alaska          AK
# 2             Arizona               Ariz.          AZ
# 3            Arkansas                Ark.          AR
# 4          California              Calif.          CA

# %%
state_abbv.to_csv('data/state_abbv.csv')

# %%
state_abbv = pd.read_csv('data/state_abbv.csv')
state_abbv.head()
# Out:
#    Unnamed: 0 State Name/District Postal Abbreviation Postal Code
# 0           0             Alabama                Ala.          AL
# 1           1              Alaska              Alaska          AK
# 2           2             Arizona               Ariz.          AZ
# 3           3            Arkansas                Ark.          AR
# 4           4          California              Calif.          CA

# %%
state_abbv[['State Name/District', 'Postal Code']].to_csv('data/state_abbv.csv', index=False)

# %%
state_abbv = pd.read_csv('data/state_abbv.csv', index_col=0)
state_abbv.head()
# Out:
#                     Postal Code
# State Name/District
# Alabama                      AL
# Alaska                       AK
# Arizona                      AZ
# Arkansas                     AR
# California                   CA

# %%
abbv_dict = state_abbv.to_dict()
abbv_dict
# Out:
# {'Postal Code': {'Alabama': 'AL',
#   'Alaska': 'AK',
#   'Arizona': 'AZ',
#   'Arkansas': 'AR',
#   'California': 'CA',
#   'Colorado': 'CO',
#   'Connecticut': 'CT',
#   'Delaware': 'DE',
#   'District of Columbia': 'DC',
#   'Florida': 'FL',
#   'Georgia': 'GA',
#   'Hawaii': 'HI',
#   'Idaho': 'ID',
#   'Illinois': 'IL',
#   'Indiana': 'IN',
#   'Iowa': 'IA',
#   'Kansas': 'KS',
#   'Kentucky': 'KY',
#   'Louisiana': 'LA',
#   'Maine': 'ME',
#   'Maryland': 'MD',
#   'Massachusetts': 'MA',
#   'Michigan': 'MI',
#   'Minnesota': 'MN',
#   'Mississippi': 'MS',
#   'Missouri': 'MO',
#   'Montana': 'MT',
#   'Nebraska': 'NE',
#   'Nevada': 'NV',
#   'New Hampshire': 'NH',
#   'New Jersey': 'NJ',
#   'New Mexico': 'NM',
#   'New York': 'NY',
#   'North Carolina': 'NC',
#   'North Dakota': 'ND',
#   'Ohio': 'OH',
#   'Oklahoma': 'OK',
#   'Oregon': 'OR',
#   'Pennsylvania': 'PA',
#   'Rhode Island': 'RI',
#   'South Carolina': 'SC',
#   'South Dakota': 'SD',
#   'Tennessee': 'TN',
#   'Texas': 'TX',
#   'Utah': 'UT',
#   'Vermont': 'VT',
#   'Virginia': 'VA',
#   'Washington': 'WA',
#   'West Virginia': 'WV',
#   'Wisconsin': 'WI',
#   'Wyoming': 'WY'}}

# %%
abbv_dict = abbv_dict['Postal Code']
abbv_dict
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virginia': 'VA',
#  'Washington': 'WA',
#  'West Virginia': 'WV',
#  'Wisconsin': 'WI',
#  'Wyoming': 'WY'}

# %%
labels = [abbv_dict[c] for c in min_wage_corr.columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 labels = [abbv_dict[c] for c in min_wage_corr.columns]
#
# Cell In[22], line 1, in <listcomp>(.0)
# ----> 1 labels = [abbv_dict[c] for c in min_wage_corr.columns]
#
# KeyError: 'Federal (FLSA)'

# %%
abbv_dict['Federal (FLSA)'] = 'FLSA'
labels = [abbv_dict[c] for c in min_wage_corr.columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 abbv_dict['Federal (FLSA)'] = 'FLSA'
# ----> 2 labels = [abbv_dict[c] for c in min_wage_corr.columns]
#
# Cell In[23], line 2, in <listcomp>(.0)
#       1 abbv_dict['Federal (FLSA)'] = 'FLSA'
# ----> 2 labels = [abbv_dict[c] for c in min_wage_corr.columns]
#
# KeyError: 'Guam'

# %%
abbv_dict['Guam'] = "GU"
abbv_dict['Puerto Rico'] = "PR"
labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names

# %%
fig = plt.figure(figsize=(12,12))  # figure so we can add axis
ax = fig.add_subplot(111)  # define axis, so we can modify
ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)  # display the matrix
ax.set_xticks(np.arange(len(labels)))  # show them all!
ax.set_yticks(np.arange(len(labels)))  # show them all!
ax.set_xticklabels(labels)  # set to be the abbv (vs useless #)
ax.set_yticklabels(labels)  # set to be the abbv (vs useless #)

plt.show()
